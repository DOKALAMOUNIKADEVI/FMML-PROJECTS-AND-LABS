# %% [markdown]
# <a href="https://colab.research.google.com/github/DOKALAMOUNIKADEVI/FMML-PROJECTS-AND-LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 12:27:36--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   215MB/s    in 0.3s
#
# 2024-03-27 12:27:38 (215 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 40567   1308.3558v1  In this paper, we propose a new stochastic alt...    cs
# 31890   1201.1670v1  Leveraging the power of increasing amounts of ...    cs
# 28409  1706.05274v2  Detecting small objects is notoriously challen...    cs
# 6533   1703.01253v5  Recurrent Neural Networks (RNN) are a type of ...  stat
# 20848  1703.09368v1  Based on a weighted knowledge graph to represe...    cs
# ...             ...                                                ...   ...
# 5715    1202.3774v1  In this paper, we study the risk bounds for sa...  stat
# 26564  1611.02637v1  In this paper, two simple principal component ...    cs
# 11068   1312.7024v1  This paper introduces a novel model-based clus...  stat
# 7411   1712.06214v1  Objective: Predict patient-specific vitals dee...  stat
# 30458  1712.02616v2  In this work we present In-Place Activated Bat...    cs
#
#                                                    title  year  \
# 40567  Fast Stochastic Alternating Direction Method o...  2013
# 31890  Customers Behavior Modeling by Semi-Supervised...  2012
# 28409  Perceptual Generative Adversarial Networks for...  2017
# 6533   Machine Learning on Sequential Data Using a Re...  2017
# 20848  Learning and inference in knowledge-based prob...  2017
# ...                                                  ...   ...
# 5715   Risk Bounds for Infinitely Divisible Distribution  2012
# 26564  Estimating motion with principal component reg...  2016
# 11068  Model-based clustering with Hidden Markov Mode...  2013
# 7411   Predicting Individual Physiologically Acceptab...  2017
# 30458  In-Place Activated BatchNorm for Memory-Optimi...  2017
#
#                                                 keywords
# 40567  [stochastic, alternating, direction, multiplie...
# 31890  [leveraging, increasing, attracting, retaining...
# 28409  [detecting, notoriously, challenging, resoluti...
# 6533   [recurrent, statistical, sequential, processed...
# 20848  [knowledge, represent, knowledge, combining, p...
# ...                                                  ...
# 5715   [independently, infinitely, divisible, distrib...
# 26564  [principal, component, regression, estimating,...
# 11068  [introduces, clustering, clustering, polynomia...
# 7411   [objective, medically, acceptable, discharge, ...
# 30458  [activated, normalization, drastically, footpr...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 40567    [stochastic, alternating, direction, multiplie...
# 31890    [leveraging, increasing, attracting, retaining...
# 28409    [detecting, notoriously, challenging, resoluti...
# 6533     [recurrent, statistical, sequential, processed...
# 20848    [knowledge, represent, knowledge, combining, p...
#                                ...
# 19800    [alternating, operational, libraries, explicit...
# 11352    [introduce, principal, differences, analyzing,...
# 7803     [completion, observations, important, discrepa...
# 11468    [algorithm, applications, statistics, especial...
# 22519    [sequential, regression, enterprise, continuou...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8736 words.
# Out of those 4544 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="efd10b7a-e779-4b06-9c82-089c72c711e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efd10b7a-e779-4b06-9c82-089c72c711e6")) {                    Plotly.newPlot(                        "efd10b7a-e779-4b06-9c82-089c72c711e6",                        [{"x":["formulation","linearized","iteration","iterations","demonstrate","experiments","alternating","complexity","significantly","algorithm","approximates","stochastic","multipliers","incrementally","algorithms","direction","convergence","customers","increasing","technique","relationship","supporting","investigates","companies","propagation","unlabeled","structural","additionally","leveraging","technologies","supervised","information","knowledge","corporate","attracting","management","techniques","available","retaining","databases","achieving","resolution","pedestrians","developing","evaluations","discriminator","narrowing","competing","detecting","adversarial","generator","superiority","difference","performance","pipelines","representation","specifically","requirement","generative","architectures","perceptual","perceived","generated","representations","notoriously","computational","characteristics","meanwhile","including","challenging","beneficial","benchmark","architecture","extensive","internally","discriminative","additional","detection","established","essentially","sequentially","limitation","outperform","artificial","recurrent","mechanism","sequential","processed","processing","reformulates","statistical","attention","classification","sequences","collected","conditional","experimental","electronic","effectiveness","annotated","activated","numerically","probability","potential","efficiently","investigated","combining","probabilistic","represent","incorporating","multivariate","regression","numerical","diagnosis","inference","intelligent","presented","comparing","facilitate","distribution","methodology","expression","boltzmann","different","computation","guarantees","optimization","supplement","dimensional","properties","simulations","challenges","associated","perspective","theoretical","underlying","relaxations","constraint","contraction","approaches","polynomial","framework","differences","computable","potentially","projection","generalized","regularized","structure","assumptions","projected","desirable","minimizing","posterior","assumption","maintained","parametrized","beginning","modulated","applications","dimension","depending","uncertain","independent","inferring","resulting","bottleneck","components","separation","variability","separates","lagrangian","resources","invariant","prediction","measurements","principle","approximation","maximally","classical","measurement","represented","characterize","predefined","molecular","interpret","interests","relationships","fingerprints","molecules","adjacency","correspondence","dictionary","attribute","arbitrarily","precisely","aggregated","chemistry","convolution","attributes"],"y":[89,5,43,25,595,612,24,218,254,808,18,125,12,9,627,67,128,10,100,233,65,20,26,10,57,36,73,60,49,28,176,725,371,2,6,53,384,283,9,68,86,116,12,57,55,17,2,26,75,101,34,46,50,896,16,362,188,30,111,128,33,12,176,268,5,265,89,26,246,264,19,208,221,183,2,98,120,363,56,28,16,19,103,138,156,105,78,29,283,1,157,163,479,110,58,105,385,25,220,80,4,15,155,128,161,50,107,158,120,62,16,106,98,47,195,66,178,81,46,229,65,46,16,781,148,59,334,1,201,215,49,114,112,78,151,117,8,105,2,428,54,567,56,6,43,45,84,49,340,60,19,31,45,36,67,9,5,5,4,460,67,32,19,123,30,135,16,118,30,21,6,5,87,74,231,40,55,119,6,89,32,91,59,18,5,15,14,71,4,5,6,35,52,51,15,18,11,4,47,65],"type":"bar"},{"x":["formulation","linearized","iteration","iterations","demonstrate","experiments","alterna ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4544,), (4544, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Transfer</span> <span style='background-color:rgba(255, 0, 0, 0.5498938428874736);'>Regression</span> <span style=''>via</span> <span style=''>Pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.353448275862069);'>Similarity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Regularization</span> <br/><br/><span style=''>Transfer</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>address</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situation</span> <span style=''>where</span> <span style=''>little</span> <span style=''>labeled</span> <span style=''>training</span> <span style=''>data</span> <span style=''>from</span> <span style=''>the</span> <span style=''>target</span> <span style=''>problem</span> <span style=''>exists</span> <span style=''>but</span> <span style=''>much</span> <span style=''>training</span> <span style=''>data</span> <span style=''>from</span> <span style=''>a</span> <span style=''>related</span> <span style=''>source</span> <span style=''>domain</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>overwhelming</span> <span style=''>majority</span> <span style=''>of</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>designed</span> <span style=''>for</span> <span style=''>simple</span> <span style=''>settings</span> <span style=''>where</span> <span style=''>the</span> <span style=''>source</span> <span style=''>and</span> <span style=''>target</span> <span style='background-color:rgba(255, 0, 0, 0.3454545454545454);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>are</span> <span style=''>almost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identical</span> <span style=''>limiting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicability</span> <span style=''>of</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>real</span> <span style=''>world</span> <span style=''>data</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>weaker</span> <span style=''>property</span> <span style=''>of</span> <span style=''>the</span> <span style=''>source</span> <span style=''>domain</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>transferred</span> <span style=''>even</span> <span style=''>when</span> <span style=''>the</span> <span style=''>source</span> <span style=''>and</span> <span style=''>target</span> <span style='background-color:rgba(255, 0, 0, 0.3454545454545454);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>diverge</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>assumes</span> <span style=''>the</span> <span style=''>source</span> <span style=''>and</span> <span style=''>target</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>share</span> <span style=''>a</span> <span style=''>Pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.353448275862069);'>Similarity</span> <span style=''>property</span> <span style=''>where</span> <span style=''>if</span> <span style=''>the</span> <span style=''>source</span> <span style=''>function</span> <span style=''>makes</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>on</span> <span style=''>a</span> <span style=''>pair</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clusterings</span> <span style=''>an</span> <span style=''>element</span> <span style=''>centric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>unifies</span> <span style=''>overlaps</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchy</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>complex</span> <span style=''>data</span> <span style=''>A</span> <span style=''>pivotal</span> <span style=''>aspect</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>analysis</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitatively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clusterings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>is</span> <span style=''>the</span> <span style=''>basis</span> <span style=''>for</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consensus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>tracking</span> <span style=''>the</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evolution</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>For</span> <span style=''>example</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style=''>requires</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>the</span> <span style=''>uncovered</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clusterings</span> <span style=''>to</span> <span style=''>planted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clusterings</span> <span style=''>or</span> <span style=''>known</span> <span style=''>metadata</span> <span style=''>Yet</span> <span style=''>as</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>measures</span> <span style=''>have</span> <span style=''>critical</span> <span style=''>biases</span> <span style=''>which</span> <span style=''>un</span> <span style=''>dermine</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>usefulness</span> <span style=''>and</span> <span style=''>no</span> <span style=''>measure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accommodates</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overlapping</span> <span style=''>and</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Constant</span> <span style=''>Time</span> <span style='background-color:rgba(255, 0, 0, 0.3454545454545454);'>Predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3130699088145896);'>Distributions</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <br/><br/><span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.625);'>compelling</span> <span style=''>features</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style='background-color:rgba(255, 0, 0, 0.5498938428874736);'>regression</span> <span style=''>is</span> <span style=''>its</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.35714285714285715);'>calibrated</span> <span style='background-color:rgba(255, 0, 0, 0.6619718309859155);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3130699088145896);'>distributions</span> <span style=''>Recent</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>inducing</span> <span style=''>point</span> <span style=''>methods</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.37931034482758624);'>drastically</span> <span style=''>sped</span> <span style=''>up</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.5058823529411764);'>likelihood</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.6619718309859155);'>posterior</span> <span style=''>mean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>leaving</span> <span style='background-color:rgba(255, 0, 0, 0.6619718309859155);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.6101694915254237);'>covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style=''>sampling</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3529411764705883);'>remaining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bottlenecks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>shortcoming</span> <span style=''>by</span> <span style=''>using</span> <span style=''>the</span> <span style=''>Lanczos</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>rapidly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3454545454545454);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.6101694915254237);'>covariance</span> <span style=''>matrix</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>which</span> <span style=''>we</span> <span style=''>refer</span> <span style=''>to</span> <span style=''>as</span> <span style=''>LOVE</span> <span style=''>(LanczOs</span> <span style=''>Variance</span> <span style=''>Estimates)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>substantially</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>time</span> <span style=''>and</span> <span style=''>space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>over</span> <span style=''>any</span> <span style=''>previous</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Predicting</span> <span style=''>Customer</span> <span style=''>Churn</span> <span style=''>Extreme</span> <span style=''>Gradient</span> <span style=''>Boosting</span> <span style=''>with</span> <span style=''>Temporal</span> <span style=''>Data</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Accurately</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicting</span> <span style=''>customer</span> <span style=''>churn</span> <span style=''>using</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>time</span> <span style=''>series</span> <span style=''>data</span> <span style=''>is</span> <span style=''>a</span> <span style=''>common</span> <span style=''>problem</span> <span style=''>facing</span> <span style=''>many</span> <span style=''>business</span> <span style=''>domains</span> <span style=''>The</span> <span style=''>creation</span> <span style=''>of</span> <span style=''>model</span> <span style=''>features</span> <span style=''>across</span> <span style=''>various</span> <span style=''>time</span> <span style=''>windows</span> <span style=''>for</span> <span style=''>training</span> <span style=''>and</span> <span style=''>testing</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>due</span> <span style=''>to</span> <span style=''>temporal</span> <span style=''>issues</span> <span style=''>common</span> <span style=''>to</span> <span style=''>time</span> <span style=''>series</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>will</span> <span style=''>explore</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>extreme</span> <span style=''>gradient</span> <span style=''>boosting</span> <span style=''>(XGBoost)</span> <span style=''>on</span> <span style=''>a</span> <span style=''>customer</span> <span style=''>dataset</span> <span style=''>with</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>temporal</span> <span style=''>features</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>create</span> <span style=''>a</span> <span style=''>highly</span> <span style=''>accurate</span> <span style=''>customer</span> <span style=''>churn</span> <span style=''>model</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>method</span> <span style=''>for</span> <span style=''>handling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>temporally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>submitted</span> <span style=''>in</span> <span style=''>the</span> <span style=''>WSDM</span> <span style=''>Cup</span> <span style=''>2018</span> <span style=''>Churn</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Challenge</span> <span style=''>and</span> <span style=''>achieved</span> <span style=''>first</span> <span style=''>place</span> <span style=''>out</span> <span style=''>of</span> <span style=''>575</span> <span style=''>teams</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10121602288984263)
# 	representation (0.12947067238912732)
# 	segmentation (0.0690271816881259)
# 	knowledge (0.132689556509299)
# 	experimental (0.1376967095851216)
# 	detection (0.1298283261802575)
# 	information (0.2592989985693848)
# 	different (0.27932761087267527)
# 	convolutional (0.12804005722460657)
# 	recognition (0.13948497854077252)
#
# Some Statistics words are:
# 	variables (0.13872255489021956)
# 	stochastic (0.13972055888223553)
# 	statistical (0.1601796407185629)
# 	theoretical (0.15818363273453093)
# 	estimation (0.17714570858283432)
# 	distribution (0.18812375249500998)
# 	algorithm (0.3967065868263473)
# 	dimensional (0.18862275449101795)
# 	inference (0.20059880239520958)
# 	regression (0.18213572854291418)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f67fa7a9-5535-43ef-8787-7ce9e55fb21d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f67fa7a9-5535-43ef-8787-7ce9e55fb21d")) {                    Plotly.newPlot(                        "f67fa7a9-5535-43ef-8787-7ce9e55fb21d",                        [{"x":["formulation","linearized","iteration","iterations","demonstrate","experiments","alternating","complexity","significantly","algorithm","approximates","stochastic","multipliers","incrementally","algorithms","direction","convergence","customers","increasing","technique","relationship","supporting","investigates","companies","propagation","unlabeled","structural","additionally","leveraging","technologies","supervised","information","knowledge","corporate","attracting","management","techniques","available","retaining","databases","achieving","resolution","pedestrians","developing","evaluations","discriminator","narrowing","competing","detecting","adversarial","generator","superiority","difference","performance","pipelines","representation","specifically","requirement","generative","architectures","perceptual","perceived","generated","representations","notoriously","computational","characteristics","meanwhile","including","challenging","beneficial","benchmark","architecture","extensive","internally","discriminative","additional","detection","established","essentially","sequentially","limitation","outperform","artificial","recurrent","mechanism","sequential","processed","processing","reformulates","statistical","attention","classification","sequences","collected","conditional","experimental","electronic","effectiveness","annotated","activated","numerically","probability","potential","efficiently","investigated","combining","probabilistic","represent","incorporating","multivariate","regression","numerical","diagnosis","inference","intelligent","presented","comparing","facilitate","distribution","methodology","expression","boltzmann","different","computation","guarantees","optimization","supplement","dimensional","properties","simulations","challenges","associated","perspective","theoretical","underlying","relaxations","constraint","contraction","approaches","polynomial","framework","differences","computable","potentially","projection","generalized","regularized","structure","assumptions","projected","desirable","minimizing","posterior","assumption","maintained","parametrized","beginning","modulated","applications","dimension","depending","uncertain","independent","inferring","resulting","bottleneck","components","separation","variability","separates","lagrangian","resources","invariant","prediction","measurements","principle","approximation","maximally","classical","measurement","represented","characterize","predefined","molecular","interpret","interests","relationships","fingerprints","molecules","adjacency","correspondence","dictionary","attribute","arbitrarily","precisely","aggregated","chemistry","convolution","attributes","compounds","aggregation","neighborhood","generalization","characterized","relational","designing","structures","important","resultant","correspond","convolutional","structured","uniformly","integrated","multimedia","characteristic","libraries","retrieval","interesting","embedding","eigenfunctions","dimensionality","reduction","differential","frequency","motivated","symmetries","coordinates","effective","euclidean","laplacian","equations","scalability","processes","conjugate","representational","dimensions","expressions","covariances","generalize","likelihoods","variational","observation","reproducing","minimization","probabilities","observations","competitive","calibrated","forecasting","following","arbitrary","defensive","uncertainty","functions","ph ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	forecaster
# 	distributing
# 	dependences
# 	corruptions
# 	idealized
# 	confounders
# 	seasonality
# 	bijective
# 	commonalities
# 	unregularized
# 	equitability
# 	phenotypes
# 	phenotype
# 	occasionally
# 	nonconjugate
# 	unraveling
# 	asymptotics
# 	precisions
# 	effectivity
# 	unnormalized
# Some words which never appear in Statistics papers:
# 	corporate
# 	defensive
# 	trustworthiness
# 	misinformation
# 	objectivity
# 	trustworthy
# 	credibility
# 	gathering
# 	phonological
# 	accelerator
# 	enormously
# 	animations
# 	monocular
# 	animation
# 	cooperative
# 	orderings
# 	articulated
# 	inheritance
# 	interpolated
# 	uncompressed

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.076544425301501e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
